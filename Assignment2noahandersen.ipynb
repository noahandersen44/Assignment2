# %%
#Noah Andersen - Assignment 2

# %%
#Problem 1

# %%
#1 Load data into dataframe
import numpy as np
import pandas as pd
df = pd.read_csv('auto_mpg.csv')
df.head()
# Out:
#     mpg  cyl   disp   hp  weight  accel  year  origin  \
# 0  18.0    8  307.0  130    3504   12.0    70       1
# 1  15.0    8  350.0  165    3693   11.5    70       1
# 2  18.0    8  318.0  150    3436   11.0    70       1
# 3  16.0    8  304.0  150    3433   12.0    70       1
# 4  17.0    8  302.0  140    3449   10.5    70       1
#
#                         name
# 0  chevrolet chevelle malibu
# 1          buick skylark 320
# 2         plymouth satellite
# 3              amc rebel sst
# 4                ford torino

# %%
#2 Get basic summary statistics (describe)
df.describe()
# Out:
#               mpg         cyl        disp          hp       weight  \
# count  392.000000  392.000000  392.000000  392.000000   392.000000
# mean    23.445918    5.471939  194.411990  104.469388  2977.584184
# std      7.805007    1.705783  104.644004   38.491160   849.402560
# min      9.000000    3.000000   68.000000   46.000000  1613.000000
# 25%     17.000000    4.000000  105.000000   75.000000  2225.250000
# 50%     22.750000    4.000000  151.000000   93.500000  2803.500000
# 75%     29.000000    8.000000  275.750000  126.000000  3614.750000
# max     46.600000    8.000000  455.000000  230.000000  5140.000000
#
#             accel        year      origin
# count  392.000000  392.000000  392.000000
# mean    15.541327   75.979592    1.576531
# std      2.758864    3.683737    0.805518
# min      8.000000   70.000000    1.000000
# 25%     13.775000   73.000000    1.000000
# 50%     15.500000   76.000000    1.000000
# 75%     17.025000   79.000000    2.000000
# ...

# %%
#3 Plot one of the features against the response variable (mpg for auto_mpg.csv)
from pandas.plotting import scatter_matrix
scatter_matrix(df,#[['mpg','cyl']],
               alpha=0.5, figsize=(10,10), diagonal='kde')
# Out:
# array([[<AxesSubplot:xlabel='mpg', ylabel='mpg'>,
#         <AxesSubplot:xlabel='cyl', ylabel='mpg'>,
#         <AxesSubplot:xlabel='disp', ylabel='mpg'>,
#         <AxesSubplot:xlabel='hp', ylabel='mpg'>,
#         <AxesSubplot:xlabel='weight', ylabel='mpg'>,
#         <AxesSubplot:xlabel='accel', ylabel='mpg'>,
#         <AxesSubplot:xlabel='year', ylabel='mpg'>,
#         <AxesSubplot:xlabel='origin', ylabel='mpg'>],
#        [<AxesSubplot:xlabel='mpg', ylabel='cyl'>,
#         <AxesSubplot:xlabel='cyl', ylabel='cyl'>,
#         <AxesSubplot:xlabel='disp', ylabel='cyl'>,
#         <AxesSubplot:xlabel='hp', ylabel='cyl'>,
#         <AxesSubplot:xlabel='weight', ylabel='cyl'>,
#         <AxesSubplot:xlabel='accel', ylabel='cyl'>,
#         <AxesSubplot:xlabel='year', ylabel='cyl'>,
#         <AxesSubplot:xlabel='origin', ylabel='cyl'>],
#        [<AxesSubplot:xlabel='mpg', ylabel='disp'>,
#         <AxesSubplot:xlabel='cyl', ylabel='disp'>,
# ...

# %%
#4 Get the X and y data ready for a sklearn model
import numpy as np
import pandas as pd
df = pd.read_csv('auto_mpg.csv')

import seaborn as sns; sns.set()
import sklearn

#X=pd.DataFrame(df['cyl'])
y=pd.DataFrame(df['mpg'])
X=df.drop(columns=['mpg','name'])

# %%
X
# Out:
#      cyl   disp   hp  weight  accel  year  origin
# 0      8  307.0  130    3504   12.0    70       1
# 1      8  350.0  165    3693   11.5    70       1
# 2      8  318.0  150    3436   11.0    70       1
# 3      8  304.0  150    3433   12.0    70       1
# 4      8  302.0  140    3449   10.5    70       1
# ..   ...    ...  ...     ...    ...   ...     ...
# 387    4  140.0   86    2790   15.6    82       1
# 388    4   97.0   52    2130   24.6    82       2
# 389    4  135.0   84    2295   11.6    82       1
# 390    4  120.0   79    2625   18.6    82       1
# 391    4  119.0   82    2720   19.4    82       1
#
# [392 rows x 7 columns]

# %%
#Problem 2

# %%
#1 Determine if you have a regression or classification problem

print("We have a regression problem. We are seeking to visualize a potential relationship/correlation between the amount of cylinders in a car and the corresponding miles per gallon the car averages.")
# Out:
# We have a regression problem. We are seeking to visualize a potential relationship/correlation between the amount of cylinders in a car and the corresponding miles per gallon the car averages.

# %%
#2 Select a reasonable model (linear regression, some kind of classification, etc.) and setup the model using sklearn

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#3 Fit the model
from sklearn.linear_model import LinearRegression
model = LinearRegression(fit_intercept=True)
model
# Out:
# LinearRegression()

# %%
#4 Determine the accuracy of the model
model.fit(X,y)
print(model.coef_)
print(model.intercept_)
# Out:
# [[-0.49337632  0.01989564 -0.01695114 -0.00647404  0.08057584  0.75077268
#    1.4261405 ]]
# [-17.21843462]

# %%
#Problem 3
#Write no more than one page (can be much shorter really...at least 100 words though) discussing the ethical considerations of the dataset and model you selected. 
print("Some ethical considerations to make when looking at this model include the potential environmental impacts of the vehicles regarding their efficiency (or lack thereof). We can see through this model which cylinder cars are the strongly efficient and inefficient, and therefore which ones are most likely to create greater emissions. It could be important to carry off of this data by looking into the geography and distribution of inefficient cars and what effect their emissions may have on local communities and populations. It would be interesting to see if there were further correlations from a population geography perspective in relation to health disparities.")
# Out:
# Some ethical considerations to make when looking at this model include the potential environmental impacts of the vehicles regarding their efficiency (or lack thereof). We can see through this model which cylinder cars are the strongly efficient and inefficient, and therefore which ones are most likely to create greater emissions. It could be important to carry off of this data by looking into the geography and distribution of inefficient cars and what effect their emissions may have on local communities and populations. It would be interesting to see if there were further correlations from a population geography perspective in relation to health disparities.
